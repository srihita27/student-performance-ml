# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

data = pd.read_csv("student_performance_300.csv")

print(data.head())
# Out:
#    Hours_Studied  Attendance  Assignments  Sleep_Hours  Previous_Score  \
# 0              7          75            6            7              81
# 1              4          66            8            5              41
# 2              8          89            7            5              42
# 3              5          82            9            6              62
# 4              7          58            4            6              94
#
#    Exam_Score
# 0         100
# 1          81
# 2         100
# 3          98
# 4         100

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hours_Studied   300 non-null    int64
#  1   Attendance      300 non-null    int64
#  2   Assignments     300 non-null    int64
#  3   Sleep_Hours     300 non-null    int64
#  4   Previous_Score  300 non-null    int64
#  5   Exam_Score      300 non-null    int64
# dtypes: int64(6)
# memory usage: 14.2 KB
#        Hours_Studied  Attendance  Assignments  Sleep_Hours  Previous_Score  \
# count      300.00000  300.000000   300.000000   300.000000      300.000000
# mean         4.92000   75.150000     6.450000     6.003333       68.393333
# std          2.64896   14.197632     1.752447     1.422463       15.334573
# min          1.00000   50.000000     4.000000     4.000000       40.000000
# 25%          3.00000   62.750000     5.000000     5.000000       56.000000
# 50%          5.00000   75.000000     6.000000     6.000000       69.000000
# 75%          7.00000   86.250000     8.000000     7.000000       82.000000
# max          9.00000   99.000000     9.000000     8.000000       94.000000
#
#        Exam_Score
# count  300.000000
# mean    91.870000
# std     10.150692
# min     54.000000
# 25%     86.000000
# 50%     96.000000
# 75%    100.000000
# max    100.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation")
plt.show()

# %%
sns.scatterplot(x="Hours_Studied", y="Exam_Score", data=data)
plt.title("Hours Studied vs Exam Score")
plt.show()

# %%
sns.scatterplot(x="Attendance", y="Exam_Score", data=data)
plt.show()
